# %%
using AutoViz
using AutomotiveDrivingModels

# %%
# adjust the dash length to something reasonable
function AutoViz.render!(rm::RenderModel, rw::Roadway)
    render!(rm, rw, lane_dash_len=3.0, lane_dash_spacing=15.0)
end

# %%
roadway = gen_straight_roadway(4, 100.0)
cars = [ArrowCar([50.0, 0.0], 0.0, color=colorant"green"),
    ArrowCar([78.0, 3.0], 0.0, color=colorant"#6B1E89"),
    ArrowCar([58.0, 6.0], 0.0, color=colorant"#6F1180"),
    ArrowCar([56.0, 9.0], 0.0, color=colorant"#4327AE"),
    ArrowCar([7.0, 6.0], 0.0, color=colorant"#D2002A"),
    ArrowCar([3.0, 3.0], 0.0, color=colorant"#B70044"),
    ]
render([roadway, cars...])
# Out:
# Cairo.CairoSurfaceBase{UInt32}(Ptr{Nothing} @0x000000000317de40, 1000.0, 600.0)
